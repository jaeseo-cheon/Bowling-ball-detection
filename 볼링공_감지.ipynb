# %% [markdown]
# <a href="https://colab.research.google.com/github/jaeseo-cheon/Bowling-ball-detection/blob/main/%EB%B3%BC%EB%A7%81%EA%B3%B5_%EA%B0%90%EC%A7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# tenserflow 재설치

# %%
# !pip install google-auth-oauthlib>=0.7.0

# %%
# !pip install protobuf==3.19.6

# %%
# !pip install protobuf>=5.26.1

# %%
# !pip install tensorflow==2.17.0

# %%
# !pip install keras==3.7.0
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %% [markdown]
# 코드 실행

# %%
# !pip install roboflow

# %%
# !pip install roboflow
# 1. 로보플로우 패키지 임포트
from roboflow import Roboflow

# 2. API 키 설정
import os
os.environ["ROBOFLOW_API_KEY"] = "9ZgVKHbXw2gzDih3Ztul"

# 3. 이미지 업로드
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
print(f"Uploaded file name: {file_name}")

# 4. 로보플로우 모델 불러오기
rf = Roboflow(api_key="9ZgVKHbXw2gzDih3Ztul")
model = rf.workspace().project("-i5ese").version(2).model

# 5. 추론 수행
results = model.predict(file_name, confidence=40, overlap=30).json()
print("Inference Results:", results)

# 6. 이미지 및 결과 시각화
import cv2
import matplotlib.pyplot as plt
image = cv2.imread(file_name)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Input Image: 공.jpg")
plt.show()
# Out:
# ...
#      <input type="file" id="files-6fac0ff9-1901-4789-a10c-2cc54cbc4152" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6fac0ff9-1901-4789-a10c-2cc54cbc4152">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
